# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import glob
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import os
import pandas as pd
import gc

# %%
hrdps = sorted(glob.glob('/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y????m??d??.nc'))
hrdps
# Out:
# ['/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m02d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m03d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m04d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m05d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m06d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m07d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m08d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m09d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m10d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m11d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m12d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m02d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m03d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m04d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m05d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m06d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m07d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m08d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m09d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m10d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m11d27.nc',
# ...
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m02d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m03d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m04d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m05d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m06d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m07d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d28.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d29.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d30.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m08d31.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d01.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d02.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d03.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d04.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d05.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d06.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d07.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d08.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d09.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d10.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d11.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d12.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d13.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d14.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d15.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d16.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d17.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d18.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d19.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d20.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d21.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d22.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d23.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d24.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d25.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d26.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d27.nc',
#  '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m09d28.nc',
#  ...]

# %%
hrdps[0]
# Out:
# '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2007m01d03.nc'

# %%
hrdps[-1]
# Out:
# '/results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2014m11d18.nc'

# %%
years = [2008, 2009, 2010, 2011, 2012]
hrdps_files_by_year = {}
for year in years:
    files = sorted(glob.glob(f"/results/forcing/atmospheric/GEM2.5/gemlam/"f"gemlam_y{year}m??d??.nc"))
    hrdps_files_by_year[year] = files
    print(year, ":", files[0], files[-1])
# Out:
# 2008 : /results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m01d01.nc /results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2008m12d31.nc
# 2009 : /results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m01d01.nc /results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2009m12d31.nc
# 2010 : /results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2010m01d01.nc /results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2010m12d31.nc
# 2011 : /results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2011m01d01.nc /results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2011m12d31.nc
# 2012 : /results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2012m01d01.nc /results/forcing/atmospheric/GEM2.5/gemlam/gemlam_y2012m12d31.nc

# %%
# Loading datasets

weights_pre_file = "/home/sallen/MEOPAR/grid/weights-gem2.5-gemlam_201702_pre22sep11.nc"
weights_post_file = "/home/sallen/MEOPAR/grid/weights-gem2.5-gemlam_201702_22sep11onward.nc"
mesh_mask_file = "/ocean/dtaneja/MOAD/analysis-dishika/grid/mesh_mask202108.nc"

ds_weights_pre = xr.open_dataset(weights_pre_file).load()
ds_weights_post = xr.open_dataset(weights_post_file).load()

with xr.open_dataset(mesh_mask_file) as ds_mesh:
    nemo_lat = ds_mesh["nav_lat"].load()
    nemo_lon = ds_mesh["nav_lon"].load()

# %%
# Converts hourly HRDPS humidity from the 266 × 256 HRDPS grid to the 898 × 398 NEMO grid

transition_time = pd.Timestamp("2011-09-22 00:00:00")

def interpolate_qair_with_weights(qair, ds_weights):
    qair = qair.transpose("time_counter", "y", "x")

    n_time = qair.sizes["time_counter"]
    source_shape = (qair.sizes["y"],qair.sizes["x"])
    n_source_cells = source_shape[0] * source_shape[1]

    source_values = (qair.values.reshape(n_time, n_source_cells).astype(np.float32))
    target_shape = ds_weights["src01"].shape

    interpolated = np.zeros((n_time, target_shape[0], target_shape[1]),dtype=np.float32)

    for n in range(1, 5):
        # The source indexes in the weights file are 1-based
        source_index = (ds_weights[f"src{n:02d}"].values.astype(np.int64)- 1)
        weight = (ds_weights[f"wgt{n:02d}"].values.astype(np.float32))

        interpolated += (source_values[:, source_index]* weight[None, :, :])

    qair_nemo = xr.DataArray(
        interpolated,
        dims=("time_counter", "y", "x"),
        coords={
            "time_counter": qair["time_counter"],
            "nav_lat": (("y", "x"), nemo_lat.values),
            "nav_lon": (("y", "x"), nemo_lon.values),
        },
        name="qair"
    )

    qair_nemo.attrs = qair.attrs.copy()
    qair_nemo.attrs["grid"] = "SalishSeaCast NEMO grid"
    qair_nemo.attrs["interpolation"] = (
        "Four-source weighted HRDPS-to-NEMO interpolation"
    )
    return qair_nemo

# %%
# Open file and interpolates

def extract_and_interpolate_hourly_qair(file):
    with xr.open_dataset(file) as ds:
        qair = ds["qair"].sortby("time_counter")
        time_index = qair.get_index("time_counter")

        if time_index.has_duplicates:
            unique_mask = ~time_index.duplicated()
            qair = qair.isel(time_counter=unique_mask)

        qair = qair.load()

    times = pd.to_datetime(qair["time_counter"].values)

    before_transition = times < transition_time
    after_transition = times >= transition_time

    pieces = []

    if before_transition.any():
        qair_pre = qair.isel(time_counter=np.where(before_transition)[0])
        interpolated_pre = interpolate_qair_with_weights(qair_pre,ds_weights_pre)
        pieces.append(interpolated_pre)

    if after_transition.any():
        qair_post = qair.isel(time_counter=np.where(after_transition)[0])
        interpolated_post = interpolate_qair_with_weights(qair_post,ds_weights_post)
        pieces.append(interpolated_post)

    qair_nemo = xr.concat(pieces,dim="time_counter").sortby("time_counter")
    return qair_nemo

# %%
sample_pre_file = hrdps_files_by_year[2008][0]
qair_nemo_pre = extract_and_interpolate_hourly_qair(sample_pre_file)

print("Shape:", qair_nemo_pre.shape)
print("Time range:",qair_nemo_pre.time_counter.values[0],"to",qair_nemo_pre.time_counter.values[-1])
# Out:
# Shape: (24, 898, 398)
# Time range: 2008-01-01T00:00:00.000000000 to 2008-01-01T23:00:00.000000000

# %%
sample_post_file = hrdps_files_by_year[2012][0]
qair_nemo_post = extract_and_interpolate_hourly_qair(sample_post_file)

print("Shape:", qair_nemo_post.shape)
print("Time range:",qair_nemo_post.time_counter.values[0],"to",qair_nemo_post.time_counter.values[-1])
# Out:
# Shape: (24, 898, 398)
# Time range: 2012-01-01T00:00:00.000000000 to 2012-01-01T23:00:00.000000000

# %%
with xr.open_dataset(mesh_mask_file) as ds_mesh:
    water_mask = (ds_mesh["tmask"].isel(t=0, z=0).load().values.astype(bool))
    nemo_lat_2d = ds_mesh["nav_lat"].load().values
    nemo_lon_2d = ds_mesh["nav_lon"].load().values
nemo_j, nemo_i = np.where(water_mask)
water_flat_indices = np.flatnonzero(water_mask.reshape(-1))
nemo_water_lat = nemo_lat_2d[water_mask]
nemo_water_lon = nemo_lon_2d[water_mask]
n_water = len(water_flat_indices)
print("NEMO grid shape:", water_mask.shape)
print("Number of surface water cells:", n_water)
# Out:
# NEMO grid shape: (898, 398)
# Number of surface water cells: 81383

# %%
def process_daily_file_to_3h_water(file):
    qair_nemo_hourly = extract_and_interpolate_hourly_qair(file)
    n_time = qair_nemo_hourly.sizes["time_counter"]

    qair_water_values = (qair_nemo_hourly.values.reshape(n_time, -1)[:, water_flat_indices].astype(np.float32))
    qair_water_hourly = xr.DataArray(qair_water_values,dims=("time_counter", "water_cell"),coords={
            "time_counter": qair_nemo_hourly["time_counter"].values,
            "water_cell": np.arange(n_water, dtype=np.int32),},name="qair",attrs=qair_nemo_hourly.attrs,)

    qair_water_3h = qair_water_hourly.resample(time_counter="3h",label="left",closed="left",origin="start_day",).mean()
    return qair_water_3h.load()

# %%
test_file = hrdps_files_by_year[2008][0]

test_3h = process_daily_file_to_3h_water(test_file)

print(test_3h)
print("Shape:", test_3h.shape)
print("Times:", test_3h.time_counter.values)
# Out:
# <xarray.DataArray 'qair' (time_counter: 8, water_cell: 81383)> Size: 3MB
# array([[0.00437713, 0.00437694, 0.00437886, ..., 0.00224176, 0.00220709,
#         0.00216781],
#        [0.003964  , 0.00396842, 0.00397606, ..., 0.00201575, 0.00197028,
#         0.00192146],
#        [0.00353609, 0.00352398, 0.00351551, ..., 0.00219021, 0.00217945,
#         0.00217055],
#        ...,
#        [0.00334919, 0.00336214, 0.00337662, ..., 0.0025652 , 0.00256278,
#         0.00256353],
#        [0.00398105, 0.00392987, 0.00388177, ..., 0.00287874, 0.00289251,
#         0.00290983],
#        [0.00462941, 0.00460646, 0.00459238, ..., 0.00331704, 0.00336446,
#         0.00341757]], shape=(8, 81383), dtype=float32)
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 64B 2008-01-01 ... 2008-01-01...
#   * water_cell    (water_cell) int32 326kB 0 1 2 3 4 ... 81379 81380 81381 81382
# Attributes:
#     level:          2 m above surface
#     long_name:      Specific Humidity
#     standard_name:  specific_humidity_2maboveground
#     units:          kg/kg
#     comment:        calculated from sea level air pressure and dewpoint tempe...
#     grid:           SalishSeaCast NEMO grid
#     interpolation:  Four-source weighted HRDPS-to-NEMO interpolation
# Shape: (8, 81383)
# Times: ['2008-01-01T00:00:00.000000000' '2008-01-01T03:00:00.000000000'
#  '2008-01-01T06:00:00.000000000' '2008-01-01T09:00:00.000000000'
#  '2008-01-01T12:00:00.000000000' '2008-01-01T15:00:00.000000000'
#  '2008-01-01T18:00:00.000000000' '2008-01-01T21:00:00.000000000']

# %%
# # Run only once
# output_dir = ("/ocean/dtaneja/MOAD/analysis-dishika/notebooks/data/hrdps_nemo_3h")
# os.makedirs(output_dir, exist_ok=True)
# hrdps_nemo_processed_files = []

# for year in years:
#     files = sorted(hrdps_files_by_year[year])
#     print(f"\nProcessing {year}: {len(files)} daily files")
#     daily_3h_results = []
#     for file_number, file in enumerate(files, start=1):
#         daily_3h = process_daily_file_to_3h_water(file)
#         daily_3h_results.append(daily_3h)

#         if (file_number == 1 or file_number % 25 == 0 or file_number == len(files)):
#             print(f"{year}: processed "f"{file_number}/{len(files)} files")

#     qair_year = xr.concat(daily_3h_results,dim="time_counter",)
#     qair_year = qair_year.sortby("time_counter")
#     time_index = qair_year.get_index("time_counter")

#     if time_index.has_duplicates:
#         unique_mask = ~time_index.duplicated()
#         qair_year = qair_year.isel(time_counter=unique_mask)

#     ds_year = qair_year.to_dataset(name="qair")

#     ds_year = ds_year.assign_coords(
#         nemo_j=("water_cell",nemo_j.astype(np.int32),),
#         nemo_i=("water_cell",nemo_i.astype(np.int32),),
#         nav_lat=("water_cell",nemo_water_lat.astype(np.float32),),
#         nav_lon=("water_cell",nemo_water_lon.astype(np.float32),),)

#     ds_year.attrs["description"] = ("Raw hourly HRDPS qair interpolated onto NEMO surface water cells, then resampled to three-hourly means.")

#     output_file = (f"{output_dir}/"f"HRDPS_NEMO_{year}_qair_3h.nc")
#     encoding = {"qair": {"dtype": "float32","zlib": True,"complevel": 4,}}
#     ds_year.to_netcdf(output_file,engine="netcdf4",encoding=encoding,)
#     hrdps_nemo_processed_files.append(output_file)

#     print("Saved:", output_file)
#     print("Shape:", ds_year["qair"].shape)
#     print("Time range:",ds_year.time_counter.values[0],"to",ds_year.time_counter.values[-1],)
#     del daily_3h_results
#     del qair_year
#     del ds_year

#     gc.collect()

# %%
hrdps_nemo_files = sorted(glob.glob("/ocean/dtaneja/MOAD/analysis-dishika/notebooks/data/hrdps_nemo_3h/HRDPS_NEMO_*_qair_3h.nc"))
ds_hrdps_nemo = xr.open_mfdataset(hrdps_nemo_files,combine="by_coords")

ds_hrdps_nemo = ds_hrdps_nemo.sortby("time_counter")

print(ds_hrdps_nemo)
print("First time:", ds_hrdps_nemo.time_counter.values[0])
print("Last time: ", ds_hrdps_nemo.time_counter.values[-1])
print("Shape:", ds_hrdps_nemo["qair"].shape)
# Out:
# <xarray.Dataset> Size: 5GB
# Dimensions:       (time_counter: 14592, water_cell: 81383)
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 117kB 2008-01-01 ... 2012-12-...
#   * water_cell    (water_cell) int32 326kB 0 1 2 3 4 ... 81379 81380 81381 81382
#     nemo_j        (water_cell) int32 326kB dask.array<chunksize=(81383,), meta=np.ndarray>
#     nemo_i        (water_cell) int32 326kB dask.array<chunksize=(81383,), meta=np.ndarray>
#     nav_lat       (water_cell) float32 326kB dask.array<chunksize=(81383,), meta=np.ndarray>
#     nav_lon       (water_cell) float32 326kB dask.array<chunksize=(81383,), meta=np.ndarray>
# Data variables:
#     qair          (time_counter, water_cell) float32 5GB dask.array<chunksize=(364, 10173), meta=np.ndarray>
# Attributes:
#     description:  Raw hourly HRDPS qair interpolated onto NEMO surface water ...
# First time: 2008-01-01T00:00:00.000000000
# Last time:  2012-12-31T21:00:00.000000000
# Shape: (14592, 81383)

# %%
# Validation: 2008
ds_hrdps_val = ds_hrdps_nemo.sel(time_counter=slice("2008-01-01", "2008-12-31 23:59:59"))
# Training: 2009–2011
ds_hrdps_train = ds_hrdps_nemo.sel(time_counter=slice("2009-01-01", "2011-12-31 23:59:59"))
# Testing: 2012
ds_hrdps_test = ds_hrdps_nemo.sel(time_counter=slice("2012-01-01", "2012-12-31 23:59:59"))

# %%
canrcm_years = [2008, 2009, 2010, 2011, 2012]
canrcm_huss_files = []

for year in canrcm_years:
    matches = sorted(glob.glob(f"/results/forcing/CanRCM5/*_{year}01_{year}12_3h_huss.nc"))
    canrcm_huss_files.append(matches[0])

print("CanRCM files:")
for file in canrcm_huss_files:
    print(file)
# Out:
# CanRCM files:
# /results/forcing/CanRCM5/sc_nam22r55lkn3-bc07_200801_200812_3h_huss.nc
# /results/forcing/CanRCM5/sc_nam22r55lkn3-bc07_200901_200912_3h_huss.nc
# /results/forcing/CanRCM5/sc_nam22r55lkn3-bc07_201001_201012_3h_huss.nc
# /results/forcing/CanRCM5/sc_nam22r55lkn3-bc07_201101_201112_3h_huss.nc
# /results/forcing/CanRCM5/sc_nam22r55lkn3-bc07_201201_201212_3h_huss.nc

# %%
from datetime import timedelta
ds_canrcm = xr.open_mfdataset(canrcm_huss_files,combine="by_coords")
ds_canrcm = ds_canrcm.sortby("time")
shifted_time = np.array([time_value - timedelta(hours=3)for time_value in ds_canrcm["time"].values])
ds_canrcm = ds_canrcm.assign_coords(time=("time", shifted_time))

print(ds_canrcm)
print("First timestamp:", ds_canrcm.time.values[0])
print("Last timestamp: ", ds_canrcm.time.values[-1])
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:       (time: 14600, bnds: 2, rlat: 320, rlon: 360)
# Coordinates:
#   * time          (time) object 117kB 2008-01-01 00:00:00 ... 2012-12-31 21:0...
#   * rlat          (rlat) float64 3kB -35.11 -34.89 -34.67 ... 34.63 34.85 35.07
#   * rlon          (rlon) float64 3kB -39.27 -39.05 -38.83 ... 39.27 39.49 39.71
#     lon           (rlat, rlon) float64 922kB dask.array<chunksize=(320, 360), meta=np.ndarray>
#     lat           (rlat, rlon) float64 922kB dask.array<chunksize=(320, 360), meta=np.ndarray>
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds     (time, bnds) object 234kB dask.array<chunksize=(2920, 2), meta=np.ndarray>
#     rotated_pole  (time) |S1 15kB b'' b'' b'' b'' b'' ... b'' b'' b'' b'' b''
#     huss          (time, rlat, rlon) float32 7GB dask.array<chunksize=(2920, 320, 360), meta=np.ndarray>
# Attributes: (12/17)
#     title:                          CanRCM4 model output prepared for CORDEX ...
#     institution:                    CCCma (Canadian Centre for Climate Modell...
#     institute_id:                   CCCma
#     driving_experiment:             , , r1i1p1
#     driving_model_ensemble_member:  r1i1p1
#     realization:                    1
#     ...                             ...
#     product:                        output
#     Conventions:                    CF-1.4
#     contact:                        cccma_info@ec.gc.ca
#     references:                     http://www.cccma.ec.gc.ca/models
#     history:                        created: 2024-09-09 22:15:26 by rcm2nc
#     data_licence:                   1) GRANT OF LICENCE - The Government of C...
# First timestamp: 2008-01-01 00:00:00
# Last timestamp:  2012-12-31 21:00:00
# /tmp/ipykernel_453328/1191316714.py:2: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds_canrcm = xr.open_mfdataset(canrcm_huss_files,combine="by_coords")

# %%
nemo_water_lat = ds_hrdps_nemo["nav_lat"].values
nemo_water_lon = ds_hrdps_nemo["nav_lon"].values

nemo_water_lon_normalized = ((nemo_water_lon + 180) % 360) - 180

lat_min = float(np.nanmin(nemo_water_lat))
lat_max = float(np.nanmax(nemo_water_lat))

lon_min = float(np.nanmin(nemo_water_lon_normalized))
lon_max = float(np.nanmax(nemo_water_lon_normalized))

print("NEMO latitude range:", lat_min, "to", lat_max)
print("NEMO longitude range:", lon_min, "to", lon_max)
# Out:
# NEMO latitude range: 47.06300735473633 to 50.92766571044922
# NEMO longitude range: -126.14797973632812 to -122.22117614746094

# %%
lat_canrcm = ds_canrcm["lat"]
lon_canrcm = ds_canrcm["lon"]

lon_canrcm_normalized = ((lon_canrcm + 180) % 360) - 180
canrcm_region_mask = ((lat_canrcm >= lat_min)& (lat_canrcm <= lat_max)
                      & (lon_canrcm_normalized >= lon_min) & (lon_canrcm_normalized <= lon_max))

rlat_indices, rlon_indices = np.where(canrcm_region_mask.values)

rlat_min = rlat_indices.min()
rlat_max = rlat_indices.max()

rlon_min = rlon_indices.min()
rlon_max = rlon_indices.max()

print("CanRCM rlat indices:", rlat_min, "to", rlat_max)
print("CanRCM rlon indices:", rlon_min, "to", rlon_max)

ds_canrcm_cut = (ds_canrcm[["huss"]].isel(rlat=slice(rlat_min, rlat_max + 1),rlon=slice(rlon_min, rlon_max + 1)))
print(ds_canrcm_cut)
# Out:
# CanRCM rlat indices: 171 to 190
# CanRCM rlon indices: 91 to 107
# <xarray.Dataset> Size: 20MB
# Dimensions:  (time: 14600, rlat: 20, rlon: 17)
# Coordinates:
#   * time     (time) object 117kB 2008-01-01 00:00:00 ... 2012-12-31 21:00:00
#   * rlat     (rlat) float64 160B 2.51 2.73 2.95 3.17 ... 6.03 6.25 6.47 6.69
#   * rlon     (rlon) float64 136B -19.25 -19.03 -18.81 ... -16.17 -15.95 -15.73
#     lon      (rlat, rlon) float64 3kB dask.array<chunksize=(20, 17), meta=np.ndarray>
#     lat      (rlat, rlon) float64 3kB dask.array<chunksize=(20, 17), meta=np.ndarray>
# Data variables:
#     huss     (time, rlat, rlon) float32 20MB dask.array<chunksize=(2920, 20, 17), meta=np.ndarray>
# Attributes: (12/17)
#     title:                          CanRCM4 model output prepared for CORDEX ...
#     institution:                    CCCma (Canadian Centre for Climate Modell...
#     institute_id:                   CCCma
#     driving_experiment:             , , r1i1p1
#     driving_model_ensemble_member:  r1i1p1
#     realization:                    1
#     ...                             ...
#     product:                        output
#     Conventions:                    CF-1.4
#     contact:                        cccma_info@ec.gc.ca
#     references:                     http://www.cccma.ec.gc.ca/models
#     history:                        created: 2024-09-09 22:15:26 by rcm2nc
#     data_licence:                   1) GRANT OF LICENCE - The Government of C...

# %%
# Validation: 2008
ds_canrcm_val = ds_canrcm_cut.sel(time=slice("2008-01-01","2008-12-31 23:59:59"))
# Training: 2009–2011
ds_canrcm_train = ds_canrcm_cut.sel(time=slice("2009-01-01","2011-12-31 23:59:59"))
# Testing: 2012
ds_canrcm_test = ds_canrcm_cut.sel(time=slice("2012-01-01","2012-12-31 23:59:59"))

# %%
def time_to_string(value):
    if isinstance(value, np.datetime64):
        return np.datetime_as_string(value,unit="s").replace("T", " ")

    if hasattr(value, "strftime"):
        return value.strftime("%Y-%m-%d %H:%M:%S")

    raise TypeError(f"Unsupported time type: {type(value)}")


def align_time_pair(ds_canrcm_split, ds_hrdps_split):
    canrcm_times = np.array([time_to_string(t)for t in ds_canrcm_split["time"].values])
    hrdps_times = np.array([time_to_string(t)for t in ds_hrdps_split["time_counter"].values])
    common_times, canrcm_idx, hrdps_idx = np.intersect1d(canrcm_times,hrdps_times,return_indices=True)
    ds_canrcm_aligned = ds_canrcm_split.isel(time=canrcm_idx)
    ds_hrdps_aligned = ds_hrdps_split.isel(time_counter=hrdps_idx)
    return ds_canrcm_aligned, ds_hrdps_aligned

# %%
ds_canrcm_val, ds_hrdps_val = align_time_pair(ds_canrcm_val,ds_hrdps_val)
ds_canrcm_train, ds_hrdps_train = align_time_pair(ds_canrcm_train,ds_hrdps_train)
ds_canrcm_test, ds_hrdps_test = align_time_pair(ds_canrcm_test,ds_hrdps_test)

# %%
print("Validation:")
print("HRDPS:", ds_hrdps_val.sizes["time_counter"])
print("CanRCM:", ds_canrcm_val.sizes["time"])

print("\nTraining:")
print("HRDPS:", ds_hrdps_train.sizes["time_counter"])
print("CanRCM:", ds_canrcm_train.sizes["time"])

print("\nTesting:")
print("HRDPS:", ds_hrdps_test.sizes["time_counter"])
print("CanRCM:", ds_canrcm_test.sizes["time"])

assert ds_hrdps_val.sizes["time_counter"] == ds_canrcm_val.sizes["time"]
assert ds_hrdps_train.sizes["time_counter"] == ds_canrcm_train.sizes["time"]
assert ds_hrdps_test.sizes["time_counter"] == ds_canrcm_test.sizes["time"]
# Out:
# Validation:
# HRDPS: 2904
# CanRCM: 2904
#
# Training:
# HRDPS: 8760
# CanRCM: 8760
#
# Testing:
# HRDPS: 2912
# CanRCM: 2912

# %%
X_hrdps_train_raw = (ds_hrdps_train["qair"].values.astype(np.float32))
X_hrdps_val_raw = (ds_hrdps_val["qair"].values.astype(np.float32))
X_hrdps_test_raw = (ds_hrdps_test["qair"].values.astype(np.float32))

print("Raw HRDPS-NEMO train:", X_hrdps_train_raw.shape)
print("Raw HRDPS-NEMO val:  ", X_hrdps_val_raw.shape)
print("Raw HRDPS-NEMO test: ", X_hrdps_test_raw.shape)
# Out:
# Raw HRDPS-NEMO train: (8760, 81383)
# Raw HRDPS-NEMO val:   (2904, 81383)
# Raw HRDPS-NEMO test:  (2912, 81383)

# %%
valid_fraction_hrdps = np.isfinite(X_hrdps_train_raw).mean(axis=0)
valid_nemo_cols = valid_fraction_hrdps > 0.95

X_hrdps_train = X_hrdps_train_raw[:, valid_nemo_cols].copy()
X_hrdps_val = X_hrdps_val_raw[:, valid_nemo_cols].copy()
X_hrdps_test = X_hrdps_test_raw[:, valid_nemo_cols].copy()

hrdps_col_mean = np.nanmean(X_hrdps_train,axis=0)

if not np.all(np.isfinite(hrdps_col_mean)):
    raise ValueError(
        "At least one retained NEMO cell has a non-finite training mean."
    )


def fill_with_training_mean(X, training_mean):
    X = X.copy()
    rows, cols = np.where(~np.isfinite(X))
    X[rows, cols] = training_mean[cols]
    return X


X_hrdps_train = fill_with_training_mean(X_hrdps_train,hrdps_col_mean)
X_hrdps_val = fill_with_training_mean(X_hrdps_val,hrdps_col_mean)
X_hrdps_test = fill_with_training_mean(X_hrdps_test,hrdps_col_mean)

print("Valid NEMO cells:", valid_nemo_cols.sum())
print("Final HRDPS train:", X_hrdps_train.shape)
print("Final HRDPS val:  ", X_hrdps_val.shape)
print("Final HRDPS test: ", X_hrdps_test.shape)
# Out:
# Valid NEMO cells: 81383
# Final HRDPS train: (8760, 81383)
# Final HRDPS val:   (2904, 81383)
# Final HRDPS test:  (2912, 81383)

# %%
valid_water_cell = (ds_hrdps_train["water_cell"].values[valid_nemo_cols])
valid_nemo_j = (ds_hrdps_train["nemo_j"].values[valid_nemo_cols])
valid_nemo_i = (ds_hrdps_train["nemo_i"].values[valid_nemo_cols])
valid_nemo_lat = (ds_hrdps_train["nav_lat"].values[valid_nemo_cols])
valid_nemo_lon = (ds_hrdps_train["nav_lon"].values[valid_nemo_cols])
print("Saved coordinate count:", len(valid_water_cell))
# Out:
# Saved coordinate count: 81383

# %%
def make_canrcm_matrix(da):
    da = da.transpose("time", "rlat", "rlon")
    n_time = da.sizes["time"]
    return (da.values.reshape(n_time, -1).astype(np.float32))

X_canrcm_train_raw = make_canrcm_matrix(ds_canrcm_train["huss"])
X_canrcm_val_raw = make_canrcm_matrix(ds_canrcm_val["huss"])
X_canrcm_test_raw = make_canrcm_matrix(ds_canrcm_test["huss"])

print("Raw CanRCM train:", X_canrcm_train_raw.shape)
print("Raw CanRCM val:  ", X_canrcm_val_raw.shape)
print("Raw CanRCM test: ", X_canrcm_test_raw.shape)
# Out:
# Raw CanRCM train: (8760, 340)
# Raw CanRCM val:   (2904, 340)
# Raw CanRCM test:  (2912, 340)

# %%
valid_fraction_canrcm = np.isfinite(X_canrcm_train_raw).mean(axis=0)
valid_canrcm_cols = valid_fraction_canrcm > 0.95

X_canrcm_train = X_canrcm_train_raw[:,valid_canrcm_cols].copy()
X_canrcm_val = X_canrcm_val_raw[:,valid_canrcm_cols].copy()
X_canrcm_test = X_canrcm_test_raw[:,valid_canrcm_cols].copy()
canrcm_col_mean = np.nanmean(X_canrcm_train,axis=0)

if not np.all(np.isfinite(canrcm_col_mean)):
    raise ValueError(
        "At least one retained CanRCM cell has a non-finite training mean."
    )

X_canrcm_train = fill_with_training_mean(X_canrcm_train,canrcm_col_mean)
X_canrcm_val = fill_with_training_mean(X_canrcm_val,canrcm_col_mean)
X_canrcm_test = fill_with_training_mean(X_canrcm_test,canrcm_col_mean)
print("Final CanRCM train:", X_canrcm_train.shape)
print("Final CanRCM val:  ", X_canrcm_val.shape)
print("Final CanRCM test: ", X_canrcm_test.shape)
# Out:
# Final CanRCM train: (8760, 340)
# Final CanRCM val:   (2904, 340)
# Final CanRCM test:  (2912, 340)

# %%
hrdps_variance_threshold = 0.98
max_hrdps_pcs = min(300,X_hrdps_train.shape[0] - 1,X_hrdps_train.shape[1])
pca_hrdps = PCA(n_components=max_hrdps_pcs,svd_solver="randomized",random_state=0)
hrdps_train_scores_all = pca_hrdps.fit_transform(X_hrdps_train)
hrdps_cumulative_variance = np.cumsum(pca_hrdps.explained_variance_ratio_)
print("HRDPS PCA components:", pca_hrdps.components_.shape)
print("HRDPS training scores:", hrdps_train_scores_all.shape)
print("Variance explained by all searched PCs:",hrdps_cumulative_variance[-1])
# Out:
# HRDPS PCA components: (300, 81383)
# HRDPS training scores: (8760, 300)
# Variance explained by all searched PCs: 0.99887764

# %%
plt.figure(figsize=(8, 5))
plt.plot(np.arange(1, len(hrdps_cumulative_variance) + 1),hrdps_cumulative_variance)
plt.axhline(hrdps_variance_threshold,linestyle="--",label="98% variance")
plt.xlabel("Number of HRDPS-on-NEMO PCs")
plt.ylabel("Cumulative explained variance")
plt.title("HRDPS humidity PCA on NEMO Water Cells")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
threshold_indices = np.where(hrdps_cumulative_variance >= hrdps_variance_threshold)[0]
n_hrdps_pcs = threshold_indices[0] + 1
print("Selected HRDPS PCs:", n_hrdps_pcs)
print("Cumulative variance:",hrdps_cumulative_variance[n_hrdps_pcs - 1])
# Out:
# Selected HRDPS PCs: 9
# Cumulative variance: 0.9806289

# %%
hrdps_train_scores = hrdps_train_scores_all[:, :n_hrdps_pcs]
hrdps_val_scores = pca_hrdps.transform(X_hrdps_val)[:, :n_hrdps_pcs]
hrdps_test_scores = pca_hrdps.transform(X_hrdps_test)[:, :n_hrdps_pcs]

print("HRDPS train scores:", hrdps_train_scores.shape)
print("HRDPS val scores:  ", hrdps_val_scores.shape)
print("HRDPS test scores: ", hrdps_test_scores.shape)
# Out:
# HRDPS train scores: (8760, 9)
# HRDPS val scores:   (2904, 9)
# HRDPS test scores:  (2912, 9)

# %%
max_canrcm_pcs = min(100,X_canrcm_train.shape[0] - 1,X_canrcm_train.shape[1])
pca_canrcm = PCA(n_components=max_canrcm_pcs,svd_solver="randomized",random_state=0)
canrcm_train_scores_all = pca_canrcm.fit_transform(X_canrcm_train)
canrcm_val_scores_all = pca_canrcm.transform(X_canrcm_val)
canrcm_test_scores_all = pca_canrcm.transform(X_canrcm_test)
canrcm_cumulative_variance = np.cumsum(pca_canrcm.explained_variance_ratio_)

print("CanRCM PCA components:", pca_canrcm.components_.shape)
print("CanRCM train scores:", canrcm_train_scores_all.shape)
print("CanRCM val scores:  ", canrcm_val_scores_all.shape)
print("CanRCM test scores: ", canrcm_test_scores_all.shape)
# Out:
# CanRCM PCA components: (100, 340)
# CanRCM train scores: (8760, 100)
# CanRCM val scores:   (2904, 100)
# CanRCM test scores:  (2912, 100)

# %%
plt.figure(figsize=(8, 5))
plt.plot(np.arange(1, len(canrcm_cumulative_variance) + 1),canrcm_cumulative_variance)
plt.xlabel("Number of CanRCM PCs")
plt.ylabel("Cumulative explained variance")
plt.title("CanRCM humidity PCA")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
canrcm_pc_candidates = range(1,max_canrcm_pcs + 1)
val_r2_scores = []
for n_canrcm_pcs_candidate in canrcm_pc_candidates:
    X_train_pc = canrcm_train_scores_all[:,:n_canrcm_pcs_candidate]
    X_val_pc = canrcm_val_scores_all[:,:n_canrcm_pcs_candidate]
    model = LinearRegression()
    model.fit(X_train_pc,hrdps_train_scores)
    hrdps_val_scores_pred_candidate = model.predict(X_val_pc)
    val_r2 = r2_score(hrdps_val_scores,hrdps_val_scores_pred_candidate,multioutput="variance_weighted")
    val_r2_scores.append(val_r2)
val_r2_scores = np.array(val_r2_scores)

# %%
best_index = np.nanargmax(val_r2_scores)
n_canrcm_pcs = list(canrcm_pc_candidates)[best_index]
best_val_r2 = val_r2_scores[best_index]

print("Best number of CanRCM PCs:", n_canrcm_pcs)
print("Best validation PC-space R²:", best_val_r2)
# Out:
# Best number of CanRCM PCs: 90
# Best validation PC-space R²: 0.8921589851379395

# %%
plt.figure(figsize=(8, 5))
plt.plot(list(canrcm_pc_candidates),val_r2_scores)
plt.axvline(n_canrcm_pcs,linestyle="--",label=f"Best = {n_canrcm_pcs} PCs")
plt.xlabel("Number of CanRCM PCs")
plt.ylabel("Validation variance-weighted R²")
plt.title("Selecting CanRCM PCs for Multiple Linear Regression")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
X_train_pc_final = canrcm_train_scores_all[:,:n_canrcm_pcs]
X_val_pc_final = canrcm_val_scores_all[:,:n_canrcm_pcs]
X_test_pc_final = canrcm_test_scores_all[:,:n_canrcm_pcs]
lr_model = LinearRegression()
lr_model.fit(X_train_pc_final,hrdps_train_scores)

hrdps_train_scores_pred = lr_model.predict(X_train_pc_final)
hrdps_val_scores_pred = lr_model.predict(X_val_pc_final)
hrdps_test_scores_pred = lr_model.predict(X_test_pc_final)

print("Regression coefficient shape:", lr_model.coef_.shape)
print("Predicted HRDPS train scores:",hrdps_train_scores_pred.shape)
print("Predicted HRDPS validation scores:",hrdps_val_scores_pred.shape)
print("Predicted HRDPS test scores:",hrdps_test_scores_pred.shape)
# Out:
# Regression coefficient shape: (9, 90)
# Predicted HRDPS train scores: (8760, 9)
# Predicted HRDPS validation scores: (2904, 9)
# Predicted HRDPS test scores: (2912, 9)

# %%
def inverse_from_selected_hrdps_pcs(scores, pca, n_pcs):
    reconstructed = np.dot(scores,pca.components_[:n_pcs, :])
    reconstructed = reconstructed + pca.mean_
    return reconstructed.astype(np.float32)

# %%
X_hrdps_val_pred = inverse_from_selected_hrdps_pcs(hrdps_val_scores_pred,pca_hrdps,n_hrdps_pcs)
X_hrdps_test_pred = inverse_from_selected_hrdps_pcs(hrdps_test_scores_pred,pca_hrdps,n_hrdps_pcs)
print("Actual validation matrix:", X_hrdps_val.shape)
print("Predicted validation matrix:", X_hrdps_val_pred.shape)
print("Actual test matrix:", X_hrdps_test.shape)
print("Predicted test matrix:", X_hrdps_test_pred.shape)
# Out:
# Actual validation matrix: (2904, 81383)
# Predicted validation matrix: (2904, 81383)
# Actual test matrix: (2912, 81383)
# Predicted test matrix: (2912, 81383)

# %%
def calculate_metrics(actual, predicted, label):
    rmse = np.sqrt(mean_squared_error(actual.ravel(),predicted.ravel()))
    mae = mean_absolute_error(actual.ravel(),predicted.ravel())
    bias = np.mean(predicted - actual)
    r2 = r2_score(actual,predicted,multioutput="variance_weighted")
    actual_std = np.std(actual, ddof=0)
    normalized_rmse = rmse / actual_std
    print(f"\n{label}")
    print("RMSE:", rmse)
    print("MAE: ", mae)
    print("Bias:", bias)
    print("R²:  ", r2)
    print("Actual standard deviation:", actual_std)
    print("Normalized RMSE:", normalized_rmse)
    print("Normalized RMSE (%):", normalized_rmse * 100)
    return {"RMSE": rmse,"MAE": mae,"Bias": bias,"R2": r2,"Normalized_RMSE": normalized_rmse,"Normalized_RMSE_percent": normalized_rmse * 100}

# %%
val_metrics = calculate_metrics(X_hrdps_val, X_hrdps_val_pred, "Validation metrics on NEMO water cells")
test_metrics = calculate_metrics(X_hrdps_test,X_hrdps_test_pred,"Test metrics on NEMO water cells")
# Out:
# Validation metrics on NEMO water cells
# RMSE: 0.0006763825207255748
# MAE:  0.0005026723374612629
# Bias: 3.9844384e-05
# R²:   0.876157283782959
# Actual standard deviation: 0.0019407122
# Normalized RMSE: 0.3485228335458996
# Normalized RMSE (%): 34.85228335458996
#
# Test metrics on NEMO water cells
# RMSE: 0.0005995414310958902
# MAE:  0.0004574835184030235
# Bias: 5.3237596e-05
# R²:   0.9009320139884949
# Actual standard deviation: 0.0019234498
# Normalized RMSE: 0.31170110606265006
# Normalized RMSE (%): 31.170110606265006

# %%
test_pc_r2 = r2_score(hrdps_test_scores,hrdps_test_scores_pred,multioutput="variance_weighted")
print("Test PC-space variance-weighted R²:", test_pc_r2)
# Out:
# Test PC-space variance-weighted R²: 0.919169008731842

# %%
def nemo_vector_to_map(vector):
    nemo_map = np.full(water_mask.shape,np.nan,dtype=np.float32)
    nemo_map[valid_nemo_j,valid_nemo_i] = vector
    return nemo_map

# %%
def plot_actual_predicted_error(time_index,X_actual,X_predicted,times):
    actual_map = nemo_vector_to_map(X_actual[time_index])
    predicted_map = nemo_vector_to_map(X_predicted[time_index])
    error_map = predicted_map - actual_map
    humidity_min = np.nanmin(np.stack([actual_map, predicted_map]))
    humidity_max = np.nanmax(np.stack([actual_map, predicted_map]))
    error_limit = np.nanmax(np.abs(error_map))
    timestamp = pd.Timestamp(times[time_index])
    fig, axes = plt.subplots(1,3,figsize=(18, 8))

    p0 = axes[0].pcolormesh(actual_map,shading="auto",vmin=humidity_min,vmax=humidity_max)
    axes[0].set_title(f"Actual HRDPS on NEMO Grid\n{timestamp}")
    plt.colorbar(p0,ax=axes[0],label="humidity (Pa)")

    p1 = axes[1].pcolormesh(predicted_map,shading="auto",vmin=humidity_min,vmax=humidity_max )
    axes[1].set_title(f"Predicted PCA + MLR\n{timestamp}")
    plt.colorbar(p1,ax=axes[1],label="humidity (Pa)")

    p2 = axes[2].pcolormesh(error_map,shading="auto",cmap="RdBu_r",vmin=-error_limit,vmax=error_limit)
    axes[2].set_title(f"Predicted − Actual\n{timestamp}")
    plt.colorbar(p2,ax=axes[2],label="Error (Pa)")

    for ax in axes:
        ax.set_xlabel("NEMO x index (i)")
        ax.set_ylabel("NEMO y index (j)")

    plt.tight_layout()
    plt.show()

# %%
test_times = ds_hrdps_test["time_counter"].values

plot_actual_predicted_error(
    time_index=0,
    X_actual=X_hrdps_test,
    X_predicted=X_hrdps_test_pred,
    times=test_times
)

plot_actual_predicted_error(
    time_index=1222,
    X_actual=X_hrdps_test,
    X_predicted=X_hrdps_test_pred,
    times=test_times
)

plot_actual_predicted_error(
    time_index=2000,
    X_actual=X_hrdps_test,
    X_predicted=X_hrdps_test_pred,
    times=test_times
)

# %%
def make_spatial_mean_timeseries(actual_matrix,predicted_matrix,times):
    actual_mean = np.mean(actual_matrix,axis=1)
    predicted_mean = np.mean(predicted_matrix,axis=1)
    timeseries = pd.DataFrame({"actual": actual_mean,"predicted": predicted_mean},index=pd.to_datetime(times))
    timeseries.index.name = "Date"
    return timeseries

# %%
val_times = ds_hrdps_val["time_counter"].values
test_times = ds_hrdps_test["time_counter"].values

humidity_timeseries_2008 = make_spatial_mean_timeseries(
    actual_matrix=X_hrdps_val,
    predicted_matrix=X_hrdps_val_pred,
    times=val_times
)

humidity_timeseries_2012 = make_spatial_mean_timeseries(
    actual_matrix=X_hrdps_test,
    predicted_matrix=X_hrdps_test_pred,
    times=test_times
)

print(humidity_timeseries_2008.head())
print()
print(humidity_timeseries_2012.head())
# Out:
#                        actual  predicted
# Date
# 2008-01-01 00:00:00  0.004010   0.003915
# 2008-01-01 03:00:00  0.003714   0.003607
# 2008-01-01 06:00:00  0.003416   0.003277
# 2008-01-01 09:00:00  0.003355   0.003189
# 2008-01-01 12:00:00  0.003420   0.003179
#
#                        actual  predicted
# Date
# 2012-01-01 00:00:00  0.003610   0.003735
# 2012-01-01 03:00:00  0.003420   0.003516
# 2012-01-01 06:00:00  0.003440   0.003371
# 2012-01-01 09:00:00  0.003700   0.003355
# 2012-01-01 12:00:00  0.003653   0.003285

# %%
fig, ax = plt.subplots(figsize=(14, 5))
ax.plot(humidity_timeseries_2008.index,humidity_timeseries_2008["actual"],label="Actual HRDPS on NEMO grid",linewidth=1.2)
ax.plot(humidity_timeseries_2008.index,humidity_timeseries_2008["predicted"],label="Predicted PCA + MLR",linewidth=1.2,alpha=0.7)
ax.set_xlim(pd.Timestamp("2008-01-01"),pd.Timestamp("2008-12-31 23:59:59"))
ax.set_xlabel("Date")
ax.set_ylabel("Spatial mean humidity (K)")
ax.set_title("Actual vs Predicted NEMO-Grid humidity — Validation 2008")
ax.legend()
ax.grid(True, alpha=0.4)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 5))
ax.plot(humidity_timeseries_2012.index,humidity_timeseries_2012["actual"],label="Actual HRDPS on NEMO grid",linewidth=1.2)
ax.plot(humidity_timeseries_2012.index,humidity_timeseries_2012["predicted"],label="Predicted PCA + MLR",linewidth=1.2,alpha=0.7)
ax.set_xlim(pd.Timestamp("2012-01-01"),pd.Timestamp("2012-12-31 23:59:59"))
ax.set_xlabel("Date")
ax.set_ylabel("Spatial mean humidity (K)")
ax.set_title("Actual vs Predicted NEMO-Grid humidity — Test 2012")
ax.legend()
ax.grid(True, alpha=0.4)
plt.tight_layout()
plt.show()

# %%
stations = {"Sand Heads": {"j": 426,"i": 293},
    "Halibut Bank": {"j": 503,"i": 261},
    "Sentry Shoal": {"j": 707,"i": 145}}

# %%
def find_station_column(station_j, station_i):
    matches = np.where((valid_nemo_j == station_j)& (valid_nemo_i == station_i))[0]
    return int(matches[0])

for station_name, station_info in stations.items():
    column = find_station_column(station_info["j"],station_info["i"])
    stations[station_name]["column"] = column
    print(station_name,"j =", station_info["j"],"i =", station_info["i"],"matrix column =", column)
# Out:
# Sand Heads j = 426 i = 293 matrix column = 44165
# Halibut Bank j = 503 i = 261 matrix column = 53329
# Sentry Shoal j = 707 i = 145 matrix column = 71870

# %%
test_times = pd.to_datetime(ds_hrdps_test["time_counter"].values)
station_timeseries = {}
station_rmse = {}
station_normalized_rmse = {}

for station_name, station_info in stations.items():
    column = station_info["column"]

    actual = X_hrdps_test[:, column]
    predicted = X_hrdps_test_pred[:, column]

    station_df = pd.DataFrame({"actual": actual,"predicted": predicted},index=test_times)
    station_df.index.name = "Date"
    rmse = np.sqrt(mean_squared_error(station_df["actual"],station_df["predicted"]))
    actual_std = np.std(station_df["actual"],ddof=0)
    normalized_rmse = rmse / actual_std
    station_timeseries[station_name] = station_df
    station_rmse[station_name] = rmse
    station_normalized_rmse[station_name] = normalized_rmse
    print(f"{station_name} RMSE: {rmse:.4f} ")
    print(f"{station_name} Normalized RMSE: {normalized_rmse:.4f} ({normalized_rmse * 100:.2f}%)")
# Out:
# Sand Heads RMSE: 0.0006
# Sand Heads Normalized RMSE: 0.2998 (29.98%)
# Halibut Bank RMSE: 0.0006
# Halibut Bank Normalized RMSE: 0.2880 (28.80%)
# Sentry Shoal RMSE: 0.0006
# Sentry Shoal Normalized RMSE: 0.2934 (29.34%)

# %%
for station_name, station_df in station_timeseries.items():
    fig, ax = plt.subplots(figsize=(14, 5))
    ax.plot(station_df.index,station_df["actual"],label="Actual HRDPS",linewidth=1.1)
    ax.plot(station_df.index,station_df["predicted"],label="Predicted PCA + MLR",linewidth=1.1,alpha=0.7)
    ax.set_xlim(pd.Timestamp("2012-01-01"),pd.Timestamp("2012-12-31 23:59:59"))
    ax.set_xlabel("Date")
    ax.set_ylabel("humidity (K)")
    ax.set_title(f"{station_name}: Actual vs Predicted humidity, 2012\n"f"RMSE = {station_rmse[station_name]:.3f} Pa")
    ax.legend()
    ax.grid(True, alpha=0.4)
    plt.tight_layout()
    plt.show()

# %%
station_rmse_table = pd.DataFrame({"Station": list(station_rmse.keys()),"RMSE_K": list(station_rmse.values()),"Normalized_RMSE": list(station_normalized_rmse.values())})
station_rmse_table["Normalized_RMSE_Percent"] = station_rmse_table["Normalized_RMSE"] * 100
average_station_rmse = station_rmse_table["RMSE_K"].mean()
average_station_normalized_rmse = station_rmse_table["Normalized_RMSE"].mean()
print(station_rmse_table.to_string(index=False))
print(f"\nAverage RMSE across the three stations: {average_station_rmse:.4f}")
print(f"Average normalized RMSE across the three stations: {average_station_normalized_rmse:.4f} ({average_station_normalized_rmse * 100:.2f}%)")
# Out:
#      Station   RMSE_K  Normalized_RMSE  Normalized_RMSE_Percent
#   Sand Heads 0.000639         0.299762                29.976227
# Halibut Bank 0.000624         0.287965                28.796478
# Sentry Shoal 0.000606         0.293392                29.339233
#
# Average RMSE across the three stations: 0.0006
# Average normalized RMSE across the three stations: 0.2937 (29.37%)

# %%
fig, axes = plt.subplots(1,3,figsize=(20, 5),sharey=True)
for ax, (station_name, station_df) in zip(axes,station_timeseries.items()):
    ax.plot(station_df.index,station_df["actual"],label="Actual HRDPS",linewidth=1.1)
    ax.plot(station_df.index,station_df["predicted"],label="Predicted PCA + MLR",linewidth=1.1,alpha=0.7)
    ax.set_xlim(pd.Timestamp("2012-01-01"),pd.Timestamp("2012-12-31 23:59:59"))
    ax.set_xlabel("Date")
    ax.set_ylabel("humidity (K)")
    ax.set_title(f"{station_name}\n"f"RMSE = {station_rmse[station_name]:.3f} Pa")
    ax.legend()
    ax.grid(True, alpha=0.4)
    ax.tick_params(axis="x",rotation=45)

fig.suptitle(
    "Actual vs Predicted humidity at NEMO Stations, 2012",
    fontsize=15
)

plt.tight_layout()
plt.show()
